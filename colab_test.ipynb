# %% [markdown]
# <a href="https://colab.research.google.com/github/praksb2428-maker/m_l_practice/blob/main/colab_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #나의 첫번째 코랩
# ##실습 내용
# - 실습1:Google의Colab으로첫번째파일생성
# - 실습2:Git레포지토리생성
# - 실습3:Colab제공기능으로github에업로드하기
#
# *이탤릭체 텍스트*

# %% [markdown]
# #Hello world 출력하기
# - print 함수 사용

# %%
#Hello world 출력하기

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ##2.Tensorflow 모듈 불러오기

# %%
import tensorflow as tf

# %% [markdown]
# ##모듈 버전 확인하기

# %%
tf.__version__
# Out:
# '2.19.0'
